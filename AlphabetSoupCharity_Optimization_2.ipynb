# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME', 'SPECIAL_CONSIDERATIONS', 'STATUS', 'ORGANIZATION'.
application_df.drop(['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS', 'STATUS', 'ORGANIZATION'], axis=1, inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#       INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0              0     5000              1
# 1         1-9999   108590              1
# 2              0     5000              0
# 3    10000-24999     6692              1
# 4  100000-499999   142590              1

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()
unique_values
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
value_counts_application_type = application_df['APPLICATION_TYPE'].value_counts()
print(value_counts_application_type)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 500
application_types_to_replace = list(value_counts_application_type[value_counts_application_type < cutoff_value].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
value_counts_classification = application_df['CLASSIFICATION'].value_counts()
print(value_counts_classification)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
value_counts_classification1 = value_counts_classification[value_counts_classification > 1]
print(value_counts_classification1)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value_classifications = 1000
classifications_to_replace = list(value_counts_classification[value_counts_classification < cutoff_value_classifications].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Review the info
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   APPLICATION_TYPE  34299 non-null  object
#  1   AFFILIATION       34299 non-null  object
#  2   CLASSIFICATION    34299 non-null  object
#  3   USE_CASE          34299 non-null  object
#  4   INCOME_AMT        34299 non-null  object
#  5   ASK_AMT           34299 non-null  int64
#  6   IS_SUCCESSFUL     34299 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.8+ MB

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_dummies = pd.get_dummies(application_df, columns=[
    'APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
    'INCOME_AMT'
])

# Display the transformed data
application_df_dummies
# Out:
#         ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0          5000              1                   False                  True
# 1        108590              1                   False                 False
# 2          5000              0                   False                 False
# 3          6692              1                   False                 False
# 4        142590              1                   False                 False
# ...         ...            ...                     ...                   ...
# 34294      5000              0                   False                 False
# 34295      5000              0                   False                 False
# 34296      5000              0                   False                 False
# 34297      5000              1                   False                 False
# 34298  36500179              0                   False                 False
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_dummies.IS_SUCCESSFUL.values
X = application_df_dummies.drop(columns="IS_SUCCESSFUL").values


# Split the preprocessed data into a training and testing dataset
X_train,X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_of_features = X_train_scaled.shape[1]
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=number_of_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 80)                2960
#
#  dense_11 (Dense)            (None, 30)                2430
#
#  dense_12 (Dense)            (None, 1)                 31
#
# ...
# Total params: 5421 (21.18 KB)
# Trainable params: 5421 (21.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5734 - accuracy: 0.7206
# Epoch 2/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5633 - accuracy: 0.7266
# Epoch 3/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5605 - accuracy: 0.7274
# Epoch 4/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5593 - accuracy: 0.7284
# Epoch 5/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5588 - accuracy: 0.7285
# Epoch 6/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7285
# Epoch 7/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5577 - accuracy: 0.7293
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7285
# Epoch 9/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7291
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5783 - accuracy: 0.7234 - 667ms/epoch - 2ms/step
# Loss: 0.5782853364944458, Accuracy: 0.7233819365501404

# %%
 Define the model1 - deep neural net,  the number of input features and hidden nodes for each layer.

number_of_features = X_train_scaled.shape[1]
nn_model1 = tf.keras.models.Sequential()

# First hidden layer
nn_model1.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=number_of_features))

# Second hidden layer
nn_model1.add(tf.keras.layers.Dense(units=50, activation='relu'))

# Third hidden layer
nn_model1.add(tf.keras.layers.Dense(units=20, activation='relu'))

# Output layer
nn_model1.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 80)                2960
#
#  dense_14 (Dense)            (None, 50)                4050
#
#  dense_15 (Dense)            (None, 20)                1020
#
#  dense_16 (Dense)            (None, 1)                 21
#
# ...
# Total params: 8051 (31.45 KB)
# Trainable params: 8051 (31.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model1.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 2ms/step - loss: 0.5736 - accuracy: 0.7201
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5621 - accuracy: 0.7257
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7280
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5593 - accuracy: 0.7282
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7297
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5582 - accuracy: 0.7296
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5576 - accuracy: 0.7298
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7299
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5566 - accuracy: 0.7301
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5770 - accuracy: 0.7231 - 693ms/epoch - 3ms/step
# Loss: 0.5769910216331482, Accuracy: 0.7231487035751343

# %%
 Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=number_of_features))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
# !pip install keras-tuner

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 5,
#  'num_layers': 5,
#  'units_0': 7,
#  'units_1': 9,
#  'units_2': 5,
#  'units_3': 3,
#  'units_4': 5,
#  'units_5': 5,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5666 - accuracy: 0.7236 - 599ms/epoch - 2ms/step
# Loss: 0.5666126012802124, Accuracy: 0.7236151695251465
